# %%
import sys
sys.path.append('..')

from src.preprocessing import load_raw_data, clean_data
from src.train import split_data, scale_features, train_logistic_regression
from src.evaluate import evaluate_model

raw_df = load_raw_data('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
cleaned_df = clean_data(raw_df)

X_train, X_test, y_train, y_test = split_data(cleaned_df)
X_train_scaled, X_test_scaled, scaler = scale_features(X_train, X_test)
model = train_logistic_regression(X_train_scaled, y_train)

results = evaluate_model(model, X_test_scaled, y_test)
print(results)
# Out:
# {'accuracy': 0.8069552874378992, 'precision': 0.659375, 'recall': 0.5641711229946524, 'f1': 0.6080691642651297, 'confusion_matrix': array([[926, 109],
#        [163, 211]])}
